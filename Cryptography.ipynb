# %%
X= "ycuf fcq kart ndn jla gamf kartdpo muj ublaf xq, jla edffeq bdfrc? d'ee cuhq jla tply d ovunaufqn flw lk xj reumm dp fcq puhj mquem, upn d\'hq bqqp dphlehqn dp paxqvlam mqrvqf vudnm lp ue-iauqnu, upn d cuhq lhqv 300 rlpkdvxqn tdeem. d ux fvudpqn dp olvdeeu yuvkuvq upn d\'x fcq flw mpdwqv dp fcq qpfdvq am uvxqn klvrqm. jla uvq plfcdpo fl xq baf gamf uplfcqv fuvoqf. d ydee ydwq jla fcq kart laf ydfc wvqrdmdlp fcq edtqm lk ycdrc cum pqhqv bqqp mqqp bqklvq lp fcdm quvfc, xuvt xj kartdpo ylvnm. jla fcdpt jla rup oqf uyuj ydfc mujdpo fcuf mcdf fl xq lhqv fcq dpfqvpqf? fcdpt uoudp, kartqv. um yq mwqut d ux rlpfurfdpo xj mqrvqf pqfylvt lk mwdqm urvlmm fcq amu upn jlav dw dm bqdpo fvurqn vdocf ply ml jla bqffqv wvqwuvq klv fcq mflvx, xuoolf. fcq mflvx fcuf ydwqm laf fcq wufcqfdr edffeq fcdpo jla ruee jlav edkq. jla'vq kartdpo nqun, tdn. d rup bq upjycqvq, upjfdxq, upn d rup tdee jla dp lhqv mqhqp capnvqn yujm, upn fcuf'm gamf ydfc xj buvq cupnm. plf lpej ux d qsfqpmdhqej fvudpqn dp apuvxqn rlxbuf, baf d cuhq urrqmm fl fcq qpfdvq uvmqpue lk fcq apdfqn mfufqm xuvdpq rlvwm upn d ydee amq df fl dfm kaee qsfqpf fl ydwq jlav xdmqvubeq umm lkk fcq kurq lk fcq rlpfdpqpf, jla edffeq mcdf. dk lpej jla rlaen cuhq tplyp ycuf apclej vqfvdbafdlp jlav edffeq 'reqhqv' rlxxqpf yum ublaf fl bvdpo nlyp awlp jla, xujbq jla ylaen cuhq cqen jlav kartdpo flpoaq. baf jla rlaenp'f, jla ndnp'f, upn ply jla'vq wujdpo fcq wvdrq, jla olnnuxp dndlf. d ydee mcdf kavj uee lhqv jla upn jla ydee nvlyp dp df. jla'vq kartdpo nqun, tdnnl."

def decipher(X="oops",times=1):
    for i in range(times):
        X=list(X)
        for i in range(len(X)):
            if X[i]=="a":
                X[i]="b"
            else:
                if X[i]=="b":
                    X[i]="c"
                else:
                    if X[i]=="c":
                        X[i]="d"
                    else:
                        if X[i]=="d":
                            X[i]="e"
                        else:
                            if X[i]=="e":
                                X[i]="f"
                            else:
                                if X[i]=="f":
                                    X[i]="g"
                                else:
                                    if X[i]=="g":
                                        X[i]="h"
                                    else:
                                        if X[i]=="h":
                                            X[i]="i"
                                        else:
                                            if X[i]=="i":
                                                X[i]="j"
                                            else:
                                                if X[i]=="j":
                                                    X[i]="k"
                                                else:
                                                    if X[i]=="k":
                                                        X[i]="l"
                                                    else:
                                                        if X[i]=="l":
                                                            X[i]="m"
                                                        else:
                                                            if X[i]=="m":
                                                                X[i]="n"
                                                            else:
                                                                if X[i]=="n":
                                                                    X[i]="o"
                                                                else:
                                                                    if X[i]=="o":
                                                                        X[i]="p"
                                                                    else:
                                                                        if X[i]=="p":
                                                                            X[i]="q"
                                                                        else:
                                                                            if X[i]=="q":
                                                                                X[i]="r"
                                                                            else:
                                                                                if X[i]=="r":
                                                                                    X[i]="s"
                                                                                else:
                                                                                    if X[i]=="s":
                                                                                        X[i]="t"
                                                                                    else:
                                                                                        if X[i]=="t":
                                                                                            X[i]="u"
                                                                                        else:
                                                                                            if X[i]=="u":
                                                                                                X[i]="v"
                                                                                            else:
                                                                                                if X[i]=="v":
                                                                                                    X[i]="w"
                                                                                                else:
                                                                                                    if X[i]=="w":
                                                                                                        X[i]="x"
                                                                                                    else:
                                                                                                        if X[i]=="x":
                                                                                                            X[i]="y"
                                                                                                        else:
                                                                                                            if X[i]=="y":
                                                                                                                X[i]="z"
                                                                                                            else:
                                                                                                                if X[i]=="z":
                                                                                                                    X[i]="a"
            
        X="".join(X)
        
    return(X)

decipher(X,27)
# Out:
# "zdvg gdr lbsu oeo kmb hbng lbsueqp nvk vcmbg yr, kmb feggfr cegsd? e'ff dvir kmb uqmz e pwvobvgro gmx ml yk sfvnn eq gdr qvik nrvfn, vqo e'ir crrq eqimfiro eq qbyrwmbn nrswrg wveon mq vf-jbvrov, vqo e dvir mirw 300 smqlewyro ueffn. e vy gwveqro eq pmweffv zvwlvwr vqo e'y gdr gmx nqexrw eq gdr rqgewr bn vwyro lmwsrn. kmb vwr qmgdeqp gm yr cbg hbng vqmgdrw gvwprg. e zeff zexr kmb gdr lbsu mbg zegd xwrsenemq gdr feurn ml zdesd dvn qrirw crrq nrrq crlmwr mq gden rvwgd, yvwu yk lbsueqp zmwon. kmb gdequ kmb svq prg vzvk zegd nvkeqp gdvg ndeg gm yr mirw gdr eqgrwqrg? gdequ vpveq, lbsurw. vn zr nxrvu e vy smqgvsgeqp yk nrswrg qrgzmwu ml nxern vswmnn gdr bnv vqo kmbw ex en creqp gwvsro wepdg qmz nm kmb crggrw xwrxvwr lmw gdr ngmwy, yvppmg. gdr ngmwy gdvg zexrn mbg gdr xvgdrges feggfr gdeqp kmb svff kmbw felr. kmb'wr lbsueqp orvo, ueo. e svq cr vqkzdrwr, vqkgeyr, vqo e svq ueff kmb eq mirw nrirq dbqowro zvkn, vqo gdvg'n hbng zegd yk cvwr dvqon. qmg mqfk vy e rtgrqneirfk gwveqro eq bqvwyro smy
# ...
